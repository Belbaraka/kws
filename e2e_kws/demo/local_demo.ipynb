# %% [markdown]
# <h1><center>Keyword Spotting - Demo</center></h1>

# %% [markdown]
# In this demo, we will use an end2end model to extract a specific set of keywords from a speech signal that ***you*** will provide

# %% [markdown]
# ![kws_diagram](demo_img.png)

# %%
from demo import *
# Out:
# Using TensorFlow backend.

# %% [markdown]
# **Let's test your improvisation skills**<br>
#
# Choose one of the following sets and try to come up with a phrase (*which makes sense*) that uses **all** the  keywords. Repetition of keywords is allowed.
#
# - **Set 1**: `people`, `because`, `think`, `world`<br>
# *eg: To preserve our <u>world</u> for the next generations, <u>people</u> need to <u>think</u> about viable solutions, <u>because</u> global warming isn’t merciful.*
# <br>
# <br>
# - **Set 2**: `something`, `different`, `actually`, `important`<br>
# *eg: Let me ask you <u>something</u>; do you <u>actually</u> believe it is <u>important</u> to schedule that meeting today? Why not a <u>different</u> day?*
# <br>
# <br>
# - **Set 3**: `another`, `percent`, `problem`, `technology`<br>
# *eg: <u>Another</u> study on the impact that <u>technology</u> has on toddlers shows that 40 <u>percent</u> of them, develop language <u>problems</u> if exposed in their early age.*
# <br>
# <br>
# - **Set 4**:  `years`, `little`, `through`, `together`<br>
# *eg: <u>Little</u> they know that we went <u>through</u> some tough <u>years</u> <u>together</u>.*

# %%
selected_set = 4
username = 'emma'

# %% [markdown]
# **Record yourself**

# %%
recorder = set_up_recorder()
recorder
# Out:
# AudioRecorder(audio=Audio(value=b'', format='webm'), stream=CameraStream(constraints={'facing_mode': 'user', '…

# %% [markdown]
# **Or upload your own file**

# %%
path2wav = None

# %% [markdown]
# **Did you say all the keywords ?**

# %%
all_kw_occurrences, sig, fs = spot_keywords(username, selected_set, recorder=recorder, model_type='dnn', shift=0.01, path2wav=None)
# Out:
# **[1/4]**: Loading test audio file and computing MFCC frames
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-a4bda86a0157> in <module>()
# ----> 1 all_kw_occurrences, sig, fs = spot_keywords(username, selected_set, recorder=recorder, model_type='dnn', shift=0.01, path2wav=None)
#
# ~/Desktop/Swisscom/Thesis/kws/e2e_kws/demo/demo.py in spot_keywords(user_id, _set, recorder, model_type, shift, w_smooth, segment_size, path2wav)
#     161     #print("[1/4]: Loading test audio file and computing MFCC frames")
#     162     if path2wav is None:
# --> 163         fs, sig = process_recording(user_id, recorder, _set)
#     164     else:
#     165         fs, sig = wav.read(path2wav)
#
# ~/Desktop/Swisscom/Thesis/kws/e2e_kws/demo/demo.py in process_recording(user_id, recorder, _set)
#     143     filename = 'set' + str(_set), user_id + '.wav'
#     144
# --> 145     sound.export(filename, format='wav')
#     146     fs, sig = wav.read(filename)
#     147
#
# /anaconda3/lib/python3.6/site-packages/pydub/audio_segment.py in export(self, out_f, format, codec, bitrate, parameters, tags, id3v2_version, cover)
#     779
#     780         out_f = _fd_or_path_or_tempfile(out_f, 'wb+')
# --> 781         out_f.seek(0)
#     782
#     783         if format == "raw":
#
# AttributeError: 'tuple' object has no attribute 'seek'

# %% [markdown]
# **Let's listen to the keywords detected**

# %%
listen2_all_kw(all_kw_occurrences, selected_set, sig)
# Out:
# ***Years***
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# *************************************
# ***Little***
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# *************************************
# ***Through***
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# *************************************
# ***Together***
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# *************************************
